# %%
#import package
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

from sklearn.preprocessing import LabelEncoder


import AllTogether as t

import seaborn as sns

# %matplotlib inline

#read dataset
results = pd.read_csv('./survey_results_public.csv')

schema = pd.read_csv('./survey_results_schema.csv')

results.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
results.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
#data wrangling
#drop some descripsive columns
result=results.drop(['Respondent'],axis=1)

# %%
result.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
#get the column names
def get_col_info(x):
    num=x.select_dtypes(include=['float','int']).columns
    cat=x.select_dtypes(include=['object']).copy().columns
    return(num,cat)


#fill the numerical NaN with mean
def fill_mean(x,num=0):
    fill_me= lambda col:col.fillna(col.mean())
    x[num]=x[num].apply(fill_me,axis=0)
    return x


#Add dummy varialbe to each the catogory
def add_dummy(x,cat=0):
    for col in  cat:
        try:
            x = pd.concat([x.drop(col, axis=1), pd.get_dummies(x[col], prefix=col, prefix_sep='_', drop_first=True)], axis=1)
        except:
            continue
    return x

#process to clean data
def clean_data(x,temp):
    
    new_lists=x.dropna(subset=[temp],axis=0)
    
    y=new_lists[temp]
 
    
    X=new_lists.drop([temp],axis=1)
    [num_temp,cat_temp]=get_col_info(X)
    X=fill_mean(X,num_temp)
    X=add_dummy(X,cat_temp)
    
    return X,y

#find the coefficient
def coef_weights(coefs, X_train):   
    '''
    Provides a dataframe that can be used to understand the most influential coefficients
    in a linear model by providing the coefficient estimates along with the name of the 
    variable attached to the coefficient.
    '''
    coefs_df = pd.DataFrame()
    coefs_df['est_int'] = X_train.columns
    coefs_df['coefs']= coefs
    coefs_df['abs_coefs'] = np.abs(coefs)
    coefs_df = coefs_df.sort_values('abs_coefs', ascending=False)
    return coefs_df

# %%
cutoffs = [1000,800,600,400,200]

# %%
#Function to input dependent variable
def fit_and_coef(x,y_input):
    [X,y]=clean_data(x,y_input)


    #Run this cell to pass your X and y to the model for testing
    r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
   
    #Get the most influent coef
    coef_df = coef_weights(lm_model.coef_, X_train)
        
    
    #A quick look at the top results
    return coef_df

# %%
coef_df=fit_and_coef(result,'CompTotal')
coef_df.head(20)

# %%
lists['neighbourhood_cleansed'].describe()
# Out:
# count         3818
# unique          87
# top       Broadway
# freq           397
# Name: neighbourhood_cleansed, dtype: object

# %%
fit_and_coef('review_scores_rating')
# Out:
# (3171, 60) (3171,)
# LinearRegression(normalize=True)
#                                   est_int        coefs    abs_coefs
# 1                    host_acceptance_rate  1795.188348  1795.188348
# 27                    review_scores_value     2.990993     2.990993
# 23              review_scores_cleanliness     2.321310     2.321310
# 34                 host_has_profile_pic_t    -2.131443     2.131443
# 22                 review_scores_accuracy     1.555048     1.555048
# 24                  review_scores_checkin     1.317642     1.317642
# 25            review_scores_communication     1.221842     1.221842
# 31  host_response_time_within a few hours    -0.909713     0.909713
# 35               host_identity_verified_t     0.788143     0.788143
# 40           cancellation_policy_moderate    -0.466104     0.466104
# 32      host_response_time_within an hour    -0.449524     0.449524
# 26                 review_scores_location     0.435662     0.435662
# ...

# %%
fit_and_coef('accommodates')
# Out:
# LinearRegression(normalize=True)
#                             est_int       coefs   abs_coefs
# 1              host_acceptance_rate  535.871966  535.871966
# 44            room_type_Shared room   -0.987263    0.987263
# 5                              beds    0.898657    0.898657
# 43           room_type_Private room   -0.568305    0.568305
# 4                          bedrooms    0.446873    0.446873
# 34           host_has_profile_pic_t   -0.369782    0.369782
# 46           bed_type_Pull-out Sofa    0.277652    0.277652
# 41              property_type_Other   -0.275168    0.275168
# 36    property_type_Bed & Breakfast   -0.263440    0.263440
# 47                bed_type_Real Bed    0.215191    0.215191
# 12                  guests_included    0.191693    0.191693
# 45                   bed_type_Futon    0.180744    0.180744
# 3                         bathrooms    0.139836    0.139836
# 25      review_scores_communication    0.126651    0.126651
# ...

# %%
sns.heatmap(result.corr(), annot=True, fmt=".2f");

#lists=lists.drop([review_scores],axis=1)

# %%
#Combine the room details
room_details=['property_type', 'room_type','accommodates', 'bathrooms', 'bedrooms','beds', 'bed_type','square_feet']
temp=lists[room_details].copy()
temp=clean_data(temp)
sns.heatmap(temp.corr(), annot=True, fmt=".2f");
#lists=lists.drop(room_details,axis=1)

# %%
#Combine the availability
availability=['availability_30', 'availability_60', 'availability_90','availability_365']
temp=lists[availability].copy()
temp=clean_data(temp)
sns.heatmap(temp.corr(), annot=True, fmt=".2f");
#lists=lists.drop(availability,axis=1)

# %%
#Combine host activeness
host_activeness={'host_response_time', 'host_response_rate','host_acceptance_rate', 'host_is_superhost', 'host_listings_count','host_has_profile_pic', 'host_identity_verified','instant_bookable','cancellation_policy', 'calculated_host_listings_count'}
temp=lists[host_activeness].copy()
temp=clean_data(temp)
sns.heatmap(temp.corr(), annot=True, fmt=".2f");
#lists=lists.drop(host_activeness,axis=1)

# %%
y=lists['price']
X=lists[room_details]
#X=lists.drop(['price'],axis=1)

X=clean_data(X)
cutoffs = [140,120,100, 80, 60,40,20]

#Run this cell to pass your X and y to the model for testing
r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
# Out:
# C:\Users\1214s\anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
y=lists['price']
X=lists[availability]
#X=lists.drop(['price'],axis=1)

X=clean_data(X)
#cutoffs = [10,8,6,4,2]

#Run this cell to pass your X and y to the model for testing
r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)

# %%
review_scores.hist();

# %%
room_details.hist();

# %%
sns.heatmap(review_scores.corr(), annot=True, fmt=".2f");

# %%
sns.heatmap(room_details.corr(), annot=True, fmt=".2f");

# %%
add_dummy(lists,cat_cols)
lists.head()
# Out:
# Index(['host_listings_count', 'review_scores_rating', 'reviews_per_month'], dtype='object')
# Index(['host_since', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_has_profile_pic',
#        'host_identity_verified', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'property_type', 'room_type',
#        'bed_type', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'extra_people', 'has_availability',
#        'calendar_last_scraped', 'requires_license', 'instant_bookable',
#        'cancellation_policy'],
#       dtype='object')
#         id  host_listings_count  accommodates  guests_included  \
# 0   241032                  3.0             4                2
# 1   953595                  6.0             4                1
# 2  3308979                  2.0            11               10
# 3  7421966                  1.0             3                1
# ...

# %%
lists[num_cols].hist();

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-4b623aa6ab22> in <module>
# ----> 1 sns.heatmap(lists.corr(), annot=True, fmt=".2f");
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     546     if square:
#     547         ax.set_aspect("equal")
# --> 548     plotter.plot(ax, cbar_ax, kwargs)
#     549     return ax
#     550
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in plot(self, ax, cax, kws)
#     345         # Annotate the cells with the formatted values
#     346         if self.annot:
# --> 347             self._annotate_heatmap(ax, mesh)
#     348
#     349
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in _annotate_heatmap(self, ax, mesh)
# ...

# %%
listings['square_feet'].isnull().mean()
# Out:
# 0.9745940282870613

# %%
calendar = pd.read_csv('./calendar.csv')
calendar.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
calendar.groupby("listing_id")['available'].value_counts()
#filter(lambda g: (g.name != 0) and (g.listing_id=='241032'))
#calendar['available'].value_counts(subset"listing_id"=="241032")
# Out:
# listing_id  available
# 3335        t            309
#             f             56
# 4291        t            365
# 5682        t            309
#             f             56
#                         ...
# 10334184    f              4
# 10339144    f            365
# 10339145    t            365
# 10340165    t            358
#             f              7
# Name: available, Length: 6863, dtype: int64

# %%
calendar["price"].isnull().value_counts()
# Out:
# False    934542
# True     459028
# Name: price, dtype: int64

# %%
calendar["available"].isnull().value_counts()
# Out:
# False    1393570
# Name: available, dtype: int64

# %%
calendar["available"].isnull().value_counts()
