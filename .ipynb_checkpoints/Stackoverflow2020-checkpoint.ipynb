# %%
'''In his project, we will investigate the decisive factors of compensation (converted) arround the world.'''
# Out:
# 'In his project, we will investigate the decisive factors of compensation (converted) arround the world.'

# %%
#import package
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

from sklearn.preprocessing import LabelEncoder


import AllTogether as t

import seaborn as sns

# %matplotlib inline

#read dataset
results = pd.read_csv('./survey_results_public.csv')

schema = pd.read_csv('./survey_results_schema.csv')

results.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
results.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
#data wrangling
"""drop some descripsive columns"""
result=results.drop(
    ['Respondent','CurrencyDesc','CurrencySymbol','CompTotal',
                     'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith',
                     'NEWDevOps','NEWDevOpsImpt','NEWJobHuntResearch','NEWJobHunt',
                     'NEWJobHunt','NEWPurchaseResearch','NEWPurpleLink',
                     'PlatformDesireNextYear','PlatformWorkedWith','Trans',
                     'SurveyEase','SurveyLength','WebframeDesireNextYear',
                     'WebframeWorkedWith'],axis=1
)
result.shape
# Out:
# (64461, 42)

# %%
#Check which column is object
result.select_dtypes(include=['object']).copy().columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age1stCode', 'CompFreq', 'Country',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith', 'NEWEdImpt', 'NEWLearn',
#        'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms', 'NEWOvertime',
#        'NEWSOSites', 'NEWStuck', 'OpSys', 'OrgSize', 'PurchaseWhat',
#        'Sexuality', 'SOAccount', 'SOComm', 'SOPartFreq', 'SOVisitFreq',
#        'UndergradMajor', 'WelcomeChange', 'YearsCode', 'YearsCodePro'],
#       dtype='object')

# %%
#should change some columns from object to numerical
obj_to_num={'Age1stCode','YearsCode', 'YearsCodePro'}
for i in obj_to_num:
    #locate those "less than 1 year" to 0.5
    temp1=result.loc[(result[i].str.len()>2) & (result[i].str.len()<17)]  
    result[i][temp1.index]=0.5
    
    #locate those "more than 50 years" to 55
    temp2=result.loc[result[i].str.len()>= 17]  
    result[i][temp2.index]=55
    
    #change all to numerical
    result[i] = pd.to_numeric(result[i])
# Out:
# <ipython-input-8-7566f46a19ef>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[i][temp1.index]=0.5
# <ipython-input-8-7566f46a19ef>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[i][temp2.index]=55

# %%
result['Country'].value_counts()
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Gabon                 1
# Liechtenstein         1
# Saint Lucia           1
# Nauru                 1
# Mali                  1
# Name: Country, Length: 183, dtype: int64

# %%
result['YearsCodePro'].describe()
# Out:
# count    46349.000000
# mean         8.518889
# std          7.901205
# min          0.500000
# 25%          3.000000
# 50%          6.000000
# 75%         12.000000
# max         55.000000
# Name: YearsCodePro, dtype: float64

# %%
result.describe()
# Out:
#                 Age    Age1stCode  ConvertedComp   WorkWeekHrs     YearsCode  \
# count  45446.000000  57900.000000   3.475600e+04  41151.000000  57684.000000
# mean      30.834111     15.755812   1.037561e+05     40.782174     12.725530
# std        9.585392      6.091219   2.268853e+05     17.816383      9.749987
# min        1.000000      0.500000   0.000000e+00      1.000000      0.500000
# 25%       24.000000     12.000000   2.464800e+04     40.000000      6.000000
# 50%       29.000000     15.000000   5.404900e+04     40.000000     10.000000
# 75%       35.000000     18.000000   9.500000e+04     44.000000     17.000000
# max      279.000000     85.000000   2.000000e+06    475.000000     55.000000
#
#        YearsCodePro
# count  46349.000000
# mean       8.518889
# std        7.901205
# min        0.500000
# 25%        3.000000
# 50%        6.000000
# 75%       12.000000
# max       55.000000

# %%
#get the column names
def get_col_info(arr):
    num=arr.select_dtypes(include=['float','int']).columns
    cat=arr.select_dtypes(include=['object']).copy().columns
    return(num,cat)


#fill the numerical NaN with mean
def fill_mean(arr,num=0):
    fill_me= lambda col:col.fillna(col.mean())
    arr[num]=arr[num].apply(fill_me,axis=0)
    return arr


#Add dummy varialbe to each the catogory
def add_dummy(arr,cat=0):
    for col in  cat:
        try:
            arr = pd.concat([arr.drop(col, axis=1), pd.get_dummies(arr[col], prefix=col, prefix_sep='_', drop_first=True)], axis=1)
        except:
            continue
    return arr

#process to clean data
def clean_data(arr,var):
    '''
    Input arr:dataset; var:dependent variable
    Output X,y: dataset for model fitting
    '''
    new_lists=arr.dropna(subset=[var],axis=0)
    
    y=new_lists[var]
 
    
    X=new_lists.drop([var],axis=1)
    [num_temp,cat_temp]=get_col_info(X)
    X=fill_mean(X,num_temp)
    X=add_dummy(X,cat_temp)
    #y=pd.to_numeric(y)
    #X=pd.to_numeric(X)
    return X,y

# %%
#find the coefficient
def coef_weights(coefs, X_train):   
    '''
    Provides a dataframe that can be used to understand the most influential coefficients
    in a linear model by providing the coefficient estimates along with the name of the 
    variable attached to the coefficient.
    '''
    coefs_df = pd.DataFrame()
    coefs_df['est_int'] = X_train.columns
    coefs_df['coefs']= coefs
    coefs_df['abs_coefs'] = np.abs(coefs)
    coefs_df = coefs_df.sort_values('abs_coefs', ascending=False)
    return coefs_df

# %%
#Function to input dependent variable
def fit_and_coef(arr,var,cut_max):
    [X,y]=clean_data(arr,var)
        
    #get the array of cutoffs
    #cut_max=X.shape[1]
    print (X.shape)
    if cut_max % 100 == 0:
        cut_max=cut_max
    else: 
        cut_max=cut_max + 100 - cut_max % 100
    cutoffs=[]
    for i in range(5,-1,-1):
        temp=int((i+1)*0.2*cut_max)
        cutoffs.append(temp)
    
    #cutoffs=[5000,4000,3000,2000,1000,500]
    print (cutoffs)
    #Run this cell to pass your X and y to the model for testing
    
    r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
   
    #Get the most influent coef
    
    coef_df = coef_weights(lm_model.coef_, X_train)
        
    
    #A quick look at the top results
    return coef_df,r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test

# %%
#let the dependent variable to be 'ConvertedComp'
[coef_df,r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test]=fit_and_coef(result,'ConvertedComp',1000)
coef_df.head(20)
# Out:
# (34756, 37500)
# [1200, 1000, 800, 600, 400, 200]
#                                                est_int          coefs  \
# 7                                      CompFreq_Weekly  393076.873024
# 43                               Country_United States  244617.942763
# 24                                     Country_Ireland  223917.897022
# 30                                      Country_Norway  191539.631227
# 42                              Country_United Kingdom  188971.690344
# 39                                 Country_Switzerland  180571.287095
# 8                                      CompFreq_Yearly -168922.935453
# 10                                   Country_Australia  158268.668419
# 29                                 Country_New Zealand  156782.660333
# 14                                      Country_Canada  154162.673236
# 37                                       Country_Spain  124435.408455
# 19                                     Country_Germany  116248.437997
# ...

# %%
#let the dependent variable to be 'ConvertedComp'
[coef_df,r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test]=fit_and_coef(result,'ConvertedComp',20000)
coef_df.head(20)
# Out:
# (34756, 37500)
# [24000, 20000, 16000, 12000, 8000, 4000]
#                                               est_int          coefs  \
# 7                               Country_United States  168919.315316
# 6                                     CompFreq_Yearly -120481.649793
# 39                   OrgSize_10,000 or more employees   40504.539727
# 38                                      OpSys_Windows  -24129.121699
# 36                                  OpSys_Linux-based  -23442.928692
# 11             Ethnicity_White or of European descent   20305.870988
# 33  NEWSOSites_Stack Overflow (public Q&A for anyo...  -18507.178505
# 15  JobSeek_I am not interested in new job opportu...   17876.192626
# 52                  SOVisitFreq_Daily or almost daily  -15547.332288
# 49  SOPartFreq_I have never participated in Q&A on...  -12450.894948
# 53                 SOVisitFreq_Multiple times per day  -12248.763354
# 47                             SOComm_Yes, definitely  -11981.441117
# ...

# %%
#let the dependent variable to be 'ConvertedComp'
[coef_df,r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test]=fit_and_coef(result,'ConvertedComp',500)
coef_df.head(20)
# Out:
# (34756, 37500)
# [600, 500, 400, 300, 200, 100]
#                                                est_int          coefs  \
# 7                                      CompFreq_Weekly  393076.873024
# 43                               Country_United States  244617.942763
# 24                                     Country_Ireland  223917.897022
# 30                                      Country_Norway  191539.631227
# 42                              Country_United Kingdom  188971.690344
# 39                                 Country_Switzerland  180571.287095
# 8                                      CompFreq_Yearly -168922.935453
# 10                                   Country_Australia  158268.668419
# 29                                 Country_New Zealand  156782.660333
# 14                                      Country_Canada  154162.673236
# 37                                       Country_Spain  124435.408455
# 19                                     Country_Germany  116248.437997
# ...

# %%
coef_df.head(30)
# Out:
#                                                est_int          coefs  \
# 7                                      CompFreq_Weekly  393076.873024
# 43                               Country_United States  244617.942763
# 24                                     Country_Ireland  223917.897022
# 30                                      Country_Norway  191539.631227
# 42                              Country_United Kingdom  188971.690344
# 39                                 Country_Switzerland  180571.287095
# 8                                      CompFreq_Yearly -168922.935453
# 10                                   Country_Australia  158268.668419
# 29                                 Country_New Zealand  156782.660333
# 14                                      Country_Canada  154162.673236
# 37                                       Country_Spain  124435.408455
# 19                                     Country_Germany  116248.437997
# ...

# %%
#let the dependent variable to be 'ConvertedComp'
# Trial without converting some catogory to numbers ("YearCodePro", etc.)
[coef_df,r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test]=fit_and_coef(result,'ConvertedComp',1000)
coef_df.head(20)
# Out:
# 37647
# [7540, 15080, 22620, 30160, 37700, 45240]
#                                                est_int          coefs  \
# 24                                     CompFreq_Weekly  392943.815065
# 60                               Country_United States  247246.297799
# 41                                     Country_Ireland  224200.451601
# 47                                      Country_Norway  192827.731086
# 59                              Country_United Kingdom  190400.601251
# 56                                 Country_Switzerland  181738.172220
# 25                                     CompFreq_Yearly -170288.407995
# 46                                 Country_New Zealand  160776.152648
# 27                                   Country_Australia  158933.873657
# 31                                      Country_Canada  156407.653657
# 54                                       Country_Spain  123920.167287
# 36                                     Country_Germany  114369.929086
# ...

# %%
r2_scores_test
# Out:
# [0.24138611161409163,
#  0.24099057706687688,
#  0.2403651769577989,
#  0.24741861192658055,
#  0.253740001235643,
#  0.25008086389641504]

# %%
#compare to the dataset dropping country information
result_nocountry=result.drop(['Country'],axis=1)
#result_nocountry=result_nocountry.drop(result_nocountry.tail(50000).index)
[coef_df,r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test]=fit_and_coef(result_nocountry,'ConvertedComp',500)
coef_df.head(20)
# Out:
# (34756, 37342)
# [600, 500, 400, 300, 200, 100]
#                                                est_int          coefs  \
# 7                                      CompFreq_Weekly  501865.631210
# 31                       Employment_Employed part-time  -86719.966791
# 32   Employment_Independent contractor, freelancer,...  -75301.312222
# 113                           OrgSize_2 to 9 employees  -56825.551546
# 8                                      CompFreq_Yearly  -53952.889415
# 117  OrgSize_Just me - I am a freelancer, sole prop...  -49352.645701
# 110                         OrgSize_10 to 19 employees  -45655.812228
# 42   JobFactors_Flex time or a flexible schedule;La...  -29141.840346
# 114                         OrgSize_20 to 99 employees  -26545.360328
# 86   NEWSOSites_Stack Overflow (public Q&A for anyo...  -26423.689235
# 108                                        OpSys_MacOS   26372.542260
# 60      LanguageWorkedWith_HTML/CSS;JavaScript;PHP;SQL  -26182.989657
# ...

# %%
r2_scores_test
# Out:
# [0.250699821088198,
#  0.24755367376188275,
#  0.2446872440346468,
#  0.24177849956551623,
#  0.23037529641126764,
#  0.2037974383432536]

# %%
sns.heatmap(result.corr(), annot=True, fmt=".2f");

#lists=lists.drop([review_scores],axis=1)
